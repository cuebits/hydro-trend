# %%
import geopandas
import pandas
import sqlite3

# %%
def db_connect():
    
    db = None
    try:
        db = sqlite3.connect(cwd + "\\hyrdo-db.sqlite")
        print("Connection to SQLite DB successfull.")
    except sqlite3.Error as e:
        print(f"The error '{e}' occured.")

    return db

# %%
world = geopandas.read_file("data\\GIS Data\\ne_10m_admin_0_countries.shp")

# %%
pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_rows', None)

# %%
nationcoderef = pandas.read_csv("data\\nations.csv")

# %%
nationcoderef
# Out:
#                Country Alpha-2 code Alpha-3 code  Numeric code  Latitude  \
# 0          Afghanistan           AF          AFG             4   33.0000
# 1              Albania           AL          ALB             8   41.0000
# 2              Algeria           DZ          DZA            12   28.0000
# 3       American Samoa           AS          ASM            16  -14.3333
# 4              Andorra           AD          AND            20   42.5000
# ..                 ...          ...          ...           ...       ...
# 251  Wallis and Futuna           WF          WLF           876  -13.3000
# 252     Western Sahara           EH          ESH           732   24.5000
# 253              Yemen           YE          YEM           887   15.0000
# 254             Zambia           ZM          ZMB           894  -15.0000
# 255           Zimbabwe           ZW          ZWE           716  -20.0000
#
#      Longitude
# 0         65.0
# 1         20.0
# 2          3.0
# 3       -170.0
# 4          1.6
# ..         ...
# 251     -176.2
# 252      -13.0
# 253       48.0
# 254       30.0
# 255       30.0
#
# [256 rows x 6 columns]

# %%
nationcoderef = nationcoderef.set_index("Alpha-2 code")
nationcoderef
# Out:
#                         Country Alpha-3 code  Numeric code  Latitude  \
# Alpha-2 code
# AF                  Afghanistan          AFG             4   33.0000
# AL                      Albania          ALB             8   41.0000
# DZ                      Algeria          DZA            12   28.0000
# AS               American Samoa          ASM            16  -14.3333
# AD                      Andorra          AND            20   42.5000
# ...                         ...          ...           ...       ...
# WF            Wallis and Futuna          WLF           876  -13.3000
# EH               Western Sahara          ESH           732   24.5000
# YE                        Yemen          YEM           887   15.0000
# ZM                       Zambia          ZMB           894  -15.0000
# ZW                     Zimbabwe          ZWE           716  -20.0000
#
#               Longitude
# Alpha-2 code
# AF                 65.0
# AL                 20.0
# DZ                  3.0
# AS               -170.0
# AD                  1.6
# ...                 ...
# WF               -176.2
# EH                -13.0
# YE                 48.0
# ZM                 30.0
# ZW                 30.0
#
# [256 rows x 5 columns]

# %%
nationcoderef.at["AF","Alpha-3 code"]
# Out:
# 'AFG'

# %%
import datetime

# %%
datetime.now()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16736/1454879144.py in <module>
# ----> 1 datetime.now()
#
# AttributeError: module 'datetime' has no attribute 'now'

# %%
str(datetime.datetime.now())
# Out:
# '2021-07-24 22:57:31.462475'
